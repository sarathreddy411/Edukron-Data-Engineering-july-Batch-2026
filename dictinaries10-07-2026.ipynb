# %%
print('helloWorld')
# Out:
# hello

# %%
#empty dectionary
d={}
d['Name']='Sarath'
d['Branch']='Data Engineering'
d['Batch']=2026
print(d)
# for keys,values in d.items():
#     print(keys,values)
    # print()
    # print(values,end=',')
# for values in d.keys:
print(d.values())
valuee=2026
for key,value in d.items():#iterating through dictoinary
    if value==valuee:
        d[key]='july 2026'## updating values
print(d)
# Out:
# {'Name': 'Sarath', 'Branch': 'Data Engineering', 'Batch': 2026}
# dict_values(['Sarath', 'Data Engineering', 2026])
# {'Name': 'Sarath', 'Branch': 'Data Engineering', 'Batch': 'july 2026'}

# %%
d={}
n=int(input("enter the dictoinary size"))
for i in range(n):
    key=input('enter key')
    value=input('enter value')
    d[key]=value
print(d)

# %%
d={}
d['Edukron']={}
d['Edukron']['Batches']={}
d['Edukron']['Batches'][2026]={}
d['Edukron']['Batches'][2026]['Names']=['Sarath',"Manoj","Narayana",'Lakshmi']
d['Edukron']['Batches'][2026]['Branch']=['DE','DS','DS','DS']
d['Edukron']['Batches'][2025]={}
d['Edukron']['Batches'][2025]['Names']=['Santhosh','Jagan','Naveen',"Bharath"]
d['Edukron']['Batches'][2025]['Branch']=['DE','DSA','DEVOPS','AZURE']
print(d)
