# %%
print("hgf")
# Out:
# hgf

# %%
int(round(10.5))
# Out:
# 10

# %%
# a='data science'
# print(a[11:2:-1])

b= "Edukron Data Science and Data Engineering Batch 2026"
print(b[0:7])
print(b[8:12])
print(b[13:20])
print(b[21:24])
print(b[25:41])
print(b[30:41])
print(b[42:47])
print(b[48:52])
print(b[13:30])
print(b[8:48])
# Out:
# Edukron
# Data
# Science
# and
# Data Engineering
# Engineering
# Batch
# 2026
# Science and Data
# Data Science and Data Engineering Batch
